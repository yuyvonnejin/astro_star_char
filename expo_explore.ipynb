# %%
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '..')

import lightkurve as lk
# Out:
# c:\Users\Yvonne Jin\Documents\code\astro_calib\venv\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
search_res = lk.search_lightcurve('KIC 11497958', author='Kepler')

search_res
# Out:
# SearchResult containing 17 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr011497958      0.0
#   1 Kepler Quarter 02 2009 Kepler    1800 kplr011497958      0.0
#   2 Kepler Quarter 03 2009 Kepler    1800 kplr011497958      0.0
#   3 Kepler Quarter 04 2010 Kepler    1800 kplr011497958      0.0
#   4 Kepler Quarter 05 2010 Kepler    1800 kplr011497958      0.0
#   5 Kepler Quarter 06 2010 Kepler    1800 kplr011497958      0.0
#   6 Kepler Quarter 07 2010 Kepler    1800 kplr011497958      0.0
#   7 Kepler Quarter 09 2011 Kepler      60 kplr011497958      0.0
#   8 Kepler Quarter 09 2011 Kepler      60 kplr011497958      0.0
#   9 Kepler Quarter 09 2011 Kepler      60 kplr011497958      0.0
#  10 Kepler Quarter 09 2011 Kepler    1800 kplr011497958      0.0
# ...

# %%
lc_collection = search_res.download_all()
lc_stitched = lc_collection.stitch()

# %%
lc_stitched
# Out:
# <KeplerLightCurve length=192380 LABEL="KIC 11497958" QUARTER=17 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                                   ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 131.51231594893034  9.9852210e-01 ...  6.0269013e-03 -2.5000077e-02
# 131.53275027558993  9.9974459e-01 ...  5.9242402e-03 -2.4986647e-02
# 131.55318450225604  1.0000775e+00 ...  6.0926797e-03 -2.5120135e-02
# 131.57361862891412  9.9738699e-01 ...  6.1537125e-03 -2.5048878e-02
# 131.59405285546381  9.9899536e-01 ...  5.8795330e-03 -2.4547111e-02
# 131.61448718189786  9.9843371e-01 ...  5.8450685e-03 -2.4538964e-02
# 131.63492130833038  9.9946171e-01 ...  5.8575463e-03 -2.4474798e-02
# 131.65535553463997  9.9995416e-01 ...  5.6235483e-03 -2.4316134e-02
# ...

# %%
lc_stitched.bin(time_bin_size=0.2).flatten().remove_outliers().fold(period = 79.9).plot()
plt.show()
